# %% [markdown]
# ## PROBABILIDADES

# %% [markdown]
# #### Librerias Importadas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Leer archivo

# %%
df_estudiantes = pd.read_csv('db/datos_estudiantes.csv', sep=';')
df_estudiantes
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# #### La columna 'goout' indica con un valor del 1 al 5 la on la que socialisa la persona, siendo 1 'muy bajo' y 5 'muy alto'.
# #### Cual es la probabilidad de conseguir una nota mayor o igual a 12 sabiendo que tiene una vida social sana.
# #### Se entiende por vida social sana cuando el valor de la columna 'goout' >= 3.

# %%
df_prob = df_estudiantes[['goout', 'G3']].copy()
df_prob.head()
# Out:
#    goout  G3
# 0      4  11
# 1      3  11
# 2      2  12
# 3      2  14
# 4      2  13

# %%
df_prob.describe()
# Out:
#             goout          G3
# count  649.000000  649.000000
# mean     3.184900   11.906009
# std      1.175766    3.230656
# min      1.000000    0.000000
# 25%      2.000000   10.000000
# 50%      3.000000   12.000000
# 75%      4.000000   14.000000
# max      5.000000   19.000000

# %%
df_prob.hist()
# Out:
# array([[<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df_prob.boxplot()
# Out:
# <Axes: >

# %%
df_prob['condicion_goout'] = np.where((df_prob['goout'] >= 3), 1, 0)
df_prob
# Out:
#      goout  G3  condicion_goout
# 0        4  11                1
# 1        3  11                1
# 2        2  12                0
# 3        2  14                0
# 4        2  13                0
# ..     ...  ..              ...
# 644      2  10                0
# 645      4  16                1
# 646      1   9                0
# 647      5  10                1
# 648      1  11                0
#
# [649 rows x 3 columns]

# %%
goout_count = df_prob['condicion_goout'].sum()
print(goout_count)
# Out:
# 456

# %%
df_prob['condicion_goout_g3'] = np.where((df_prob['goout'] >= 3) & (df_prob['G3'] >=     12), 1, 0)
df_prob
# Out:
#      goout  G3  condicion_goout  condicion_goout_g3
# 0        4  11                1                   0
# 1        3  11                1                   0
# 2        2  12                0                   0
# 3        2  14                0                   0
# 4        2  13                0                   0
# ..     ...  ..              ...                 ...
# 644      2  10                0                   0
# 645      4  16                1                   1
# 646      1   9                0                   0
# 647      5  10                1                   0
# 648      1  11                0                   0
#
# [649 rows x 4 columns]

# %%
goout_g3_count = df_prob['condicion_goout_g3'].sum()
print(goout_g3_count)
# Out:
# 233

# %%
probabilidad = goout_g3_count/goout_count
print(f"La probabilidad de obtener una nota mayor o igual a 12 teniendo una vida social sana es de: {probabilidad}")
# Out:
# La probabilidad de obtener una nota mayor o igual a 12 teniendo una vida social sana es de: 0.5109649122807017

# %%
nombre = "Lucas"
bienvenida = "hola " + nombre + " como estás"
print(bienvenida)
# Out:
# hola Lucas como estás
