# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customer_Age`?

# %%
# Media de 'Customers_Age'
print(f"La media del Atributo 'Customer_Age': {sales['Customer_Age'].mean()}")
# Out:
# La media del Atributo 'Customer_Age': 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde', 
                           figsize=(14, 6));

# %%
# your code goes here
sales['Customer_Age'].plot(kind='box', 
                           vert=False, 
                           figsize=(14,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
print(f"La media de la columna 'Order_Quantity': {sales['Order_Quantity'].mean()}")
# Out:
# La media de la columna 'Order_Quantity': 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', 
                             bins=30, 
                             figsize=(14,6));

# %%
sales['Order_Quantity'].plot(kind='box', 
                             vert=False, 
                             figsize=(14,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# How many sales per year do we have?

# %%
# your code goes here
year_counts = sales['Year'].value_counts()
print("Las ventas por año fueron las siguientes: \n", year_counts, "\n")
print("Y el promedio de ventas por año es de: ", year_counts.mean())
# Out:
# Las ventas por año fueron las siguientes:
#  Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64
#
# Y el promedio de ventas por año es de:  18839.333333333332

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
year_counts.plot(kind='pie', 
                 autopct='%1.1f%%', 
                 figsize=(6,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
month_counts = sales['Month'].value_counts()
print("Las ventas por mes fueron las siguientes: \n", month_counts, "\n")
print("Y el promedio de ventas por mes es de: ", month_counts.mean())
# Out:
# Las ventas por mes fueron las siguientes:
#  Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64
#
# Y el promedio de ventas por mes es de:  9419.666666666666

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
month_counts.plot(kind='bar', 
                  color='skyblue', 
                  figsize=(14, 6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales_country = sales['Country'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales_country.plot(kind='bar', 
                   figsize=(10,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
product_unique = sales['Product'].unique()
product_unique
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
product_count = sales['Product'].value_counts()

product_count.head(10).plot(kind='bar', 
                            color='skyblue', 
                            figsize=(12, 6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', 
           x='Unit_Cost',
           y='Unit_Price', 
           color='skyblue', 
           edgecolor='black',  
           grid='True', 
           figsize=(8,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', 
           x=['Order_Quantity'], 
           y=['Profit'], 
           figsize=(8,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Profit', 'Country']].boxplot(by='Country', 
                                     figsize=(10,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age', 'Country']].boxplot(by='Country', 
                                           figsize=(12,6));

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %% [markdown]
# ##### Es mas eficiente hacerlo

# %%
# your code goes here
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].astype(str).agg('-'.join, axis=1)    # Convierte las columnas a texto y concatena en una sola columna de fecha usando una operación vectorizada.
sales.head()                                                                                    # Más eficiente que `apply` con `lambda` debido a que evita el procesamiento fila por fila.
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# And if you try with this
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x.iloc[0], x.iloc[1], x.iloc[2]), axis=1)
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
ax = sales['Calculated_Date'].value_counts().sort_index().plot(kind='line', 
                                                          grid=True,
                                                          figsize=(25,6));

# COnfigura el localizador 'principal' del eje x para mostrar 'ticks' en cada año.
ax.xaxis.set_major_locator(mdates.YearLocator())
# Configura el localizador 'secundario' del eje x para mostrar 'ticks' el día 1 de cada 2 meses.
ax.xaxis.set_minor_locator(mdates.MonthLocator(bymonthday=1, interval=2))
# Formatear el eje principal para mostrar el año completo (YYYY)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
# Formatear el eje secundario para mostrar los meses abreviados (MMM)
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))

# Añadir títulos
plt.title('Conteo de Ventas por Fecha')
plt.xlabel('Fecha')
plt.ylabel('Conteo de Ventas')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] += 50
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
orders_canada_france = sales.query('Country in ["France", "Canada"]').value_counts().sum()
print("Las ventas hechas en Canada y France son:", orders_canada_france)
# Out:
# Las ventas hechas en Canada y France son: 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
orders_bike_racks_canada = sales.query("Sub_Category ==  'Bike Racks' and Country == 'Canada'").value_counts().sum()
print("El total de ventas de 'Bike Racing' es de: ", orders_bike_racks_canada)
# Out:
# El total de ventas de 'Bike Racing' es de:  104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
orders_state_france = sales.query("Country == 'France'" )['State'].value_counts()
orders_state_france
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
orders_state_france.plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales_category = sales['Product_Category'].value_counts()
sales_category
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales_category.plot(kind='pie',  
                    autopct='%1.2f%%',  # Muestra los porcentajes en el gráfico
                    figsize=(6,6),
                    wedgeprops={'edgecolor': 'black'},  # Añade borde a las porciones
                    explode=[0.1] * len(sales_category),
                    shadow=True)   # Resalta todas las porciones

plt.title('Distribución de Categorías')
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
orders_acc_sub = sales.query("Product_Category == 'Accessories'")['Sub_Category'].value_counts()
orders_acc_sub
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
orders_acc_sub.plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
bikes = sales.query("Product_Category == 'Bikes'")['Sub_Category'].value_counts()
bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
bikes.plot(kind='pie', 
           autopct='%1.1f%%',
           wedgeprops={'edgecolor': 'Black'},
           explode=[0.05] * len(sales_category),
           shadow=True,
           figsize=(6,6))

plt.title("Sub Categories")
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar');

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
revenue_500 = (sales.query("Customer_Gender == 'M'")['Revenue'] > 500).sum()
print(revenue_500)
# Out:
# 23342

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
# 5 ventas con mayores ingresos, dado la condición anterior.
filtered_revenues = sales.query("Customer_Gender == 'M' and Revenue > 500")
top_5_revenues = filtered_revenues.sort_values(by='Revenue', ascending=False).head(5)

print("Las 5 ventas con mayores ingresos fueron las siguientes:")
top_5_revenues
# Out:
# Las 5 ventas con mayores ingresos fueron las siguientes:
#              Date  Day  Month  Year  Customer_Age             Age_Group  \
# 112073 2015-07-24   24   July  2015            52        Adults (35-64)
# 112072 2013-07-24   24   July  2013            52        Adults (35-64)
# 71129  2011-07-08    8   July  2011            22           Youth (<25)
# 68671  2011-07-05    5   July  2011            26  Young Adults (25-34)
# 70307  2011-04-30   30  April  2011            44        Adults (35-64)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 68671                M     Canada  British Columbia            Bikes
# 70307                M     Canada  British Columbia            Bikes
#
# ...

# %%
# 5 ventas con mayores ingresos (General)
print("Las 5 ventas con mayores ingresos fueron las siguientes:")
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
# Las 5 ventas con mayores ingresos fueron las siguientes:
#              Date  Day  Month  Year  Customer_Age             Age_Group  \
# 112073 2015-07-24   24   July  2015            52        Adults (35-64)
# 112072 2013-07-24   24   July  2013            52        Adults (35-64)
# 71129  2011-07-08    8   July  2011            22           Youth (<25)
# 59919  2011-03-20   20  March  2011            29  Young Adults (25-34)
# 68671  2011-07-05    5   July  2011            26  Young Adults (25-34)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 59919                F    Germany            Bayern            Bikes
# 68671                M     Canada  British Columbia            Bikes
#
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
sales.nlargest(1, 'Revenue')
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()
sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58124      2015-07-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
print("El promedio es:", sales.query("Revenue > 10000")['Order_Quantity'].mean())
# Out:
# El promedio es: 3.689265536723164

# %%
cond = sales['Revenue'] > 10_000
print("El promedio es:", sales.loc[cond, 'Order_Quantity'].mean())
# Out:
# El promedio es: 3.689265536723164

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
print("El promedio es:", sales.query("Revenue < 10000")['Order_Quantity'].mean())
# Out:
# El promedio es: 11.914539380997528

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
sales.query("Year == 2016 and Month == 'May'").shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
orders_mjj_16 = sales.query("Year == 2016 and Month in ['May', 'June', 'July']")
print("Fueron:", orders_mjj_16.shape[0])
# Out:
# Fueron: 12164

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))
sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values (2016).

# %%
# your code goes here
sales.query("Year == 2016")[['Month', 'Profit']].plot(kind='box', 
                                                      by='Month', 
                                                      grid=True,
                                                      figsize=(14, 6))

plt.title('Distribución de Profit por Mes en 2016')
plt.xlabel('Mes')
plt.ylabel('Profit')

plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
print("El precio con el impuesto agregado sería: ")
sales.query("Country == 'United States'")['Unit_Price'] * 1.072
# Out:
# El precio con el impuesto agregado sería:
# 22        128.640
# 23        128.640
# 34        128.640
# 35        128.640
# 38        128.640
#            ...
# 113021     68.608
# 113022     68.608
# 113023     68.608
# 113024     68.608
# 113025     68.608
# Name: Unit_Price, Length: 39206, dtype: float64

# %%
tax = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072
print("El precio con el impuesto agregado sería: ") 
tax
# Out:
# El precio con el impuesto agregado sería:
# 22        128.640
# 23        128.640
# 34        128.640
# 35        128.640
# 38        128.640
#            ...
# 113021     68.608
# 113022     68.608
# 113023     68.608
# 113024     68.608
# 113025     68.608
# Name: Unit_Price, Length: 39206, dtype: float64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
